# %%
import pandas as pd

# %%
df = pd.ExcelFile(r'C:\Users\Victor Wright\Documents\IGP\Clients.xlsx')

# %%
Andrew = pd.read_excel(df, 'Andrew')
Michelle = pd.read_excel(df, 'Michelle')
Abraham = pd.read_excel(df, 'Abraham')

# %%
Andrew
Michelle
Abraham
# Out:
#         Month  Income   Rent  Food   Car  Water  Gas and Electric  Cellular  \
# 0     January    9700   3000   320   550     23            129.85        15
# 1    February    9700   3000   320   550     23            129.85        15
# 2       March    9700   3000   320   550     23            129.85        15
# 3       April    9700   3000   320   550     23            114.85        15
# 4         May    9700   3000   320   550     23            114.85        15
# 5        June    4850   3000   320   550     23            114.85        15
# 6        July    9700   3000   320   550     23            114.85        15
# 7      August    9700   3000   320   550     23            114.85        15
# 8   September    9700   3000   320   550     23            114.85        15
# 9     October    9700   3000   320   550     23            114.85        15
# 10   November    9700   3000   320   550     23            114.85        15
# ...

# %%
#National Statistics
medianSalary = 35000
